# %%
#Welcome to TDPM's first data analysis project

# %%
#What we are trying to achieve in this project?
# 1. We will be working with the CO2 Emission Data Set on Kaggle - s.umd.edu/class/spring2020/cmsc422-0101/

# 2. What is this data set? 

#   This data set contains CO2 emissions data of different makes and models of cars published by the Government of Canada. 

# 3. We would like to answer questions like "How one car company compares with another?", "Which model/s offered
# by a manufacturer emits less pollution, quintessentially leading up to the million dollar question, "Things to consider
# while buying your next car" - Don't forget, combustion engine vehicles will be disbarred from production starting 2030 
# in many countries including the United States.

# %%
#Loading in some essential libraries which will help us perceieve this massive data in user friendly ways and ways which
# make sense to the common buyer
import pandas as pd
import numpy as np

# %%
#Here comes our pandas data frame where we will store our data 
df = pd.read_csv(r "⁩/⁨Users/⁨sandeepdhal/⁨Desktop⁩/⁨Projects⁩/⁨Emissions Data Analysis/archive/CO2 Emissions_Canada.csv⁩")
# Out:
#   File "<ipython-input-18-a42018ddbaf7>", line 2
#     df = pd.read_csv(r "⁩/⁨Users/⁨sandeepdhal/⁨Desktop⁩/⁨Projects⁩/⁨Emissions Data Analysis/archive/CO2 Emissions_Canada.csv⁩")
#                                                                                                                              ^
# SyntaxError: invalid syntax
